# %% [markdown]
# # This notebook will be mainly used for the capstone project of IBM Professional Data Science Certificate.

# %%
import pandas as pd
import numpy as np
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
